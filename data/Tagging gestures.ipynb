# %%
import math
import nltk
import re
import all_data_handler

users = all_data_handler.UserData()

# %%
def tag_object(original):
	tags = []
	#Matches robots, robot, bot, bots, etc. 
	robots = re.compile("bot|group|swarm|orange|red", re.I)
	crate = re.compile("crate", re.I)
	targetA = re.compile("area a|box a| a$|to a,|^a$", re.I)
	targetB = re.compile("area b|box b| b$|to b,|^b$", re.I)
	whitespace = re.compile("whitespace|ground|screen|white area", re.I)
	
	toCheck = [(robots, "r"), (crate, "c"), (targetA, "a"), (targetB, "b"), (whitespace, "w")]
	for compiled, tag in toCheck:
		if re.search(compiled, original):
			tags.append(tag)
	return tags

# %%
#From https://en.wikibooks.org/wiki/Algorithm_Implementation/Strings/Levenshtein_distance#Python
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1 # j+1 instead of j since previous_row and current_row are one character longer
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row
    
    return previous_row[-1]

# %%
all_task_strs = []
for participant in users.data.keys():
		for task in users.data[participant]["tasks"].keys():
			#We're building a string representation of the user's action on the task
			# Types           Targets
			#-------------    -------------
			# drag 		 D    whitespace  w
			# draw       W    robots      r
			# ui         U    crate       c
			# tap        T    area a      a
			# doubletap  2    area b      b
			# tripletap  3    unclear     _
			# hold       H
			# pinch      P
			# rev pinch  R
			# lasso      L
			# box select B
			# voice      V
			# other      O

			task_str = ""

			for event in users.data[participant]["tasks"][task]:
				#Skip memos and examples
				if event["event_type"] == "memo" or event["example"]:
					continue

				#Get objects for most events
				if "objects" in event.keys():
					#Convert the event type to a code
					eType = event["event_type"]
					if eType == "ui":
						task_str += "U"
					elif eType == "other":
						task_str += "O"
					elif eType == "drag" and event["draw"] is not None:
						task_str += "W"
					elif eType == "drag" and event["draw"] is None:
						task_str += "D"
					elif eType == "pinch" and event["reverse"]:
						task_str += "R"
					elif eType == "pinch" and not event["reverse"]:
						task_str += "P"
					elif eType == "tap" and event["count"] > 1:
						task_str += str(event["count"])
					elif eType == "tap" and event["count"] == 1:
						task_str += "T"
					elif eType == "tap" and event["hold"]:
						task_str += "H"
					elif eType == "lasso":
						task_str += "L"
					elif eType == "box_select":
						task_str += "B"
					
					#Now add the tag objects
					obj = " ".join(event["objects"])
					obj = obj.replace("\"", "")
					obj = obj.lower()
					tags = tag_object(obj)
					if len(tags) > 0:
						task_str += "".join(tags)
					else:
						task_str += "_"

				elif event["event_type"] == "voice_command":
					task_str += "V"

					obj = " ".join(event["command"])
					obj = obj.replace("\"", "")
					obj = obj.lower()
					tags = tag_object(obj)
					if len(tags) > 0:
						task_str += "".join(tags)
					else:
						task_str += "_"
					
			taskName = users.taskNumberToName(int(task), participant)
					
			all_task_strs.append((participant, task, taskName, task_str))

# %%
#Import the data from the hand-coding of the strategies, so I have an idea of my ground truth
import csv
new_task_strs = []
with open('command_strategies.csv', 'rb') as csvfile:
    r = csv.reader(csvfile, delimiter=',')
    tasks = r.next()
    #For each row of the csv file, which describes all of a user's strategies
    for row in r:
        user = str(row[0])
        #For every task that that user did
        for index, task in enumerate(tasks[2:]):
            #Find the corresponding task string and add it to the new task strs
            for tstr in all_task_strs:
                if tstr[0] == user and tstr[2] == task:
                    #import pdb; pdb.set_trace()
                    temp = (tstr[0], tstr[1], tstr[2], tstr[3], row[index+2])
                    new_task_strs.append(temp)

# %%
#Set up a distance lookup table. This might take a while
# dlt = {}
# for t1 in new_task_strs:
#     dlt[t1] = {}
#     for t2 in new_task_strs:
#         #Only look within tasks
#         if t2[1] == t1[1]:
#             dlt[t1][t2] = levenshtein(t1[3], t2[3])

# %%
#get a distance array that scipi can deal with and a list of data it can be registered against
# data_list = []
# distance_list = []
# for pair1 in dlt.keys():
#     for pair2 in dlt[pair1].keys():
#         data_list.append((pair1, pair2))
#         distance_list.append(dlt[pair1][pair2])

# %%
#Build a distance lookup that is just upper triangular, rather than all pairs
import itertools

combi_dist = {}
all_pairs = itertools.combinations(new_task_strs, 2)
for pair in all_pairs:
    #Only look at pairs where the task matches
    if pair[0][1] == pair[1][1]:
        if pair[0] not in combi_dist.keys():
            combi_dist[pair[0]] = {}    
        combi_dist[pair[0]][pair[1]] = levenshtein(pair[0][3], pair[1][3])

# %%
results = []
for task in combi_dist.keys():
    #Get the ground truth value
    truth = task[4]
    #Get the k nearest neighbors, starting with neighbors
    d = 0
    neighbors = []
    k = 5
    
    #Get the k nearest neighbors, starting at 0 and going up (levenshtein gives integer distance)
    while len(neighbors) < k:
        for canidate in combi_dist[task]:
            if combi_dist[task][canidate] == d:
                neighbors.append((canidate, d))
                #Could have enough neighbors at this distance to go over k
                if len(neighbors) == k:
                    break
        #Next furthest neighbors
        d += 1
        #if distance ends up exceeding furthest neighbor, quit
        if d > max(combi_dist[task].values()):
            break
    
    #For the neighbors, count the strategies, and average the distance
    counts = {}
    avg_d = 0
    for n, distance in neighbors:
        if n[4] in counts.keys():
            counts[n[4]] += 1
        else:
            counts[n[4]] = 1
        avg_d += float(distance)
    avg_d = avg_d/float(len(neighbors))
    
    #Get the predicted value
    guess = max(counts, key=counts.get)
    results.append((truth, guess, avg_d))

# %%
for result in results:
    print "{}|{}|{}".format(result[0],result[1],result[2])
# Out:
# select/drag|drag robot|10.0
# drag|drag|0.6
# drag|drag|2.0
# drag robot|drag robot|8.2
# 2x select/move|drag|2.8
# border|to & around|1.8
# border|border|1.2
# draw wall|doubletap whitespace|1.2
# drag|drag|0.4
# 2x select/tap|drag|7.2
# rev pinch|squiggle|2.0
# select/drag crate|drag crate|4.8
# position/move|position/move|13.6
# cut|cut|0.0
# tap|tap|0.4
# 2x select/drag|2x select/drag|4.4
# 2x select/drag|2x select/drag|0.6
# position, no move|position/move|9.6
# cut/drag|2x select/drag|14.0
# position/move|position/move|3.2
# draw line behind robots|tap robot|1.2
# drag back|doubletap robot|1.0
# select/ui|tap|0.0
# 2x select/drag|drag|3.8
# drag|drag|0.0
# other robots push offscreen|drag offscreen|9.2
# drag crate|drag crate|10.5
# drag robot|drag robot|0.0
# doubletap|select/ui|0.8
# sweep around screen|select/drag around|2.0
# select/drag around|border|1.2
# drag|drag|3.2
# voice |drag|5.2
# border|border|1.6
# ui remove|edge|4.6
# corner|pinch|0.6
# around screen|border|1.2
# 2x select/move|drag|3.0
# ui delete|drag offscreen|1.0
# doubletap robot|tap robot|1.4
# select/ui/draw|select/draw|4.4
# rev pinch|rev pinch|0.6
# select/drag|drag robot|1.0
# draw square|draw square|1.4
# select & path|border|3.0
# rev pinch|chop|0.8
# drag robot|drag robot|0.0
# 2x select/move|2x select/move|6.0
# cut & drag|drag|1.6
# 4f spread|select, draw square|4.0
# doubletap whitespace|doubletap robot|1.2
# to & around|draw square|3.0
# 2x select/drag|chop|1.6
# tap robot|tap robot|0.0
# around screen|around screen|0.8
# single moves|select, draw square|34.4
# group moves|squiggle|13.8
# ui select|doubletap robot|1.6
# select/ui|tap|3.4
# select, draw square|draw square|3.4
# drag|drag|1.2
# drag|drag|0.4
# border|border|5.2
# ui delete|drag offscreen|1.0
# drag|pinch|0.8
# partial drag around|around screen|2.2
# corner|drag offscreen|3.4
# tap robot|tap robot|0.4
# voice|pinch|2.6
# drag|drag|0.0
# select/tap|tap|1.4
# 2x select/drag|select/r pinch|3.8
# spread/sweep|chop|2.6
# voice|squiggle|3.0
# 2x select/move|2x select/move|4.0
# 5f scatter|5f scatter|0.2
# 5f scatter|5f scatter|0.6
# position/move|position/move|6.0
# drag offscreen|doubletap whitespace|1.0
# drag|drag|3.6
# border|border|2.0
# squiggle|group moves|4.8
# drag offscreen|drag offscreen|2.6
# 2x select/move|2x select/move|2.8
# drag offscreen|to & around|0.6
# position/move|drag crate|2.8
# border|select/drag around|4.0
# select/drag|select/drag|1.8
# to & around|border|5.6
# drag|drag|0.0
# lasso|cut|0.8
# 2x select/drag|drag|10.2
# set waypoints|to & around|13.2
# multiple select and draw parts|single moves|27.2
# sweep|chop|5.2
# position/move|position/move|4.4
# voice |chop|2.0
# tap|tap|2.0
# drag robot|drag robot|7.8
# 2x select/move|drag|4.0
# ui mark|ui recolor|0.6
# ui/draw|around screen|6.2
# hold, ui remove|pinch|2.0
# select/pinch|around screen|2.6
# border|select, to & around|10.0
# sweep|select/drag|4.6
# single moves|2x select/drag|41.4
# drag robot|select/drag|3.4
# drag back|chop|1.8
# 2x select/drag|2x select/drag|4.6
# drag robot|drag robot|0.0
# drag|drag|1.2
# draw wall|tap robot|2.4
# rasied hand pull back|chop|1.0
# select/waypoint|select/draw|30.2
# position/move|position/move|7.6
# 2x select/move|2x select/move|1.6
# spread/sweep|chop|1.6
# tap/ui|select/rev pinch|3.0
# group moves|group moves|11.2
# select, draw square|draw square|2.0
# 2x select/move|2x select/move|4.8
# drag|drag|1.2
# 2x select/move|2x select/move|5.0
# border|select/drag around|1.4
# 2x select/move|2x select/move|4.0
# draw square|draw square|2.4
# draw squiggle|tap|1.6
# to & around|corner|0.8
# drag|drag|2.4
# partial drag around|border|0.4
# drag crate|drag crate|0.4
# ui/waypoint|position/move|4.4
# draw square|single moves|9.2
# tap robot|doubletap robot|0.6
# drag robot|drag robot|4.4
# drag|drag|4.6
# draw wall|draw wall|2.6
# select/rev pinch|rev pinch|1.6
# position, no move|drag crate|4.8
# drag|drag|2.0
# 2x select/move|2x select/move|4.0
# voice/draw|select/draw|2.4
# tap crate tap a|position/move|8.0
# draw "10" in box A|drag|3.0
# select/drag around|select/drag around|3.8
# around screen|select/drag around|3.6
# multi pinch|drag|7.8
# drag crate|drag crate|0.0
# single moves|2x select/move|20.0
# 2x select/drag|2x select/drag|1.0
# drag crate|position/move|2.8
# drag|drag|0.0
# select/redirect|flat hand robots|2.4
# voice, no interaction|draw square|1.6
# select/r pinch|select/r pinch|2.0
# flat hand robots|tap robot|3.0
# drag|drag|1.0
# tap whitespace|tap robot|0.8
# drag crate|position/move|8.2
# draw square|select, draw square|1.8
# select, formation ui|draw square|1.4
# tap robot|tap robot|0.0
# sweep|select/drag|2.6
# select/4f scatter|group moves|16.0
# draw wall|doubletap whitespace|0.8
# multi select/drag partway around|select/drag around|13.4
# position/move|select/drag crate|4.8
# draw "X"|chop|1.6
# draw square|draw square|7.2
# drag crate|drag crate|3.2
# single moves|single moves|10.2
# single moves|select/drag|37.2
# cut|single moves|2.2
# pinch|pinch|0.0
# rev pinch|rev pinch|0.4
# select/ui|drag from robots|1.0
# position/move|position/move|21.0
# drag|drag|0.8
# drag|drag|2.6
# single moves|2x select/drag|14.4
# 2x select/drag|select/drag|10.0
# drag|2x select/drag|5.6
# single moves|single moves|6.2
# drag|drag|1.6
# lasso|select/ui|1.0
# ui remove|pinch|1.6
# drag|drag|4.0
# voice, draw square|draw square|2.4
# multiple sweeps|drag|5.0
# 2x select/drag|select/drag|4.5
# draw square|draw square|0.4
# spread 2f tap|select/drag|5.5
# pinch|pinch|0.8
# select/tap|sweep|1.8
# select/drag around|select/drag around|2.0
# move away|tap|2.0
# voice|border|1.8
# select, draw square|draw square|2.2
# position/move|drag crate|3.8
# drag robot|drag robot|4.8
# select/ui|5f scatter|1.0
# tap robot|draw "X"|3.66666666667
# patrol ui|border|2.0
# push|drag|4.0
# corner|drag offscreen|2.6
# position/move|position/move|1.8
# 2x select/move|drag|2.6
# tap crate, robot, A|position/move|4.0
# multi drag back|doubletap robot|0.8
# select/5f scatter|select/rev pinch|1.6
# tap|tap|1.0
# drag|drag|0.0
# single moves|single moves|10.6
# around screen|draw squiggle|1.0
# doubletap whitespace|doubletap robot|0.8
# drag|drag|0.4
# position/move|position/move|3.6
# drag|drag|0.8
# patrol ui|border|0.8
# lasso|select/ui|0.8
# to & around|to & around|0.6
# voice/draw|around screen|3.8
# draw circle whitespace|tap|2.0
# offscreen garbage bin|bottom of screen|1.0
# move away|select/drag around|5.2
# select/drag|drag|2.0
# drag|select/drag|3.5
# select, to & around|border|4.0
# move fist in circle over, tap|tap|1.4
# select/drag|select/drag|1.2
# fist circle, move edge|edge|3.2
# cut & push|2x select/move|6.2
# tap, move corner|leave behind|4.0
# tap|cut|0.8
# drag robots back|tap robot|3.0
# multiple drag|drag|2.0
# 2h drag|cut & drag|3.2
# 2x select/drag|2x select/drag|3.4
# select/ui/draw|ui/draw|5.4
# spread/sweep|chop|0.6
# doubletap|border|1.6
# sweep|drag|4.0
# multi drag|drag|0.2
# drag|drag|2.0
# drag crate|drag crate|1.4
# position/move|drag crate|7.6
# border|border|0.6
# ui/waypoint|position/move|5.4
# single moves|drag|3.6
# single moves|2x select/tap|29.0
# ui mark|tap|2.4
# drag robot|drag robot|0.0
# rev pinch|chop|1.4
# drag robot|drag robot|3.2
# select/draw "X"|select/ui|3.2
# drag|drag|2.8
# drag offscreen|drag|3.2
# drag crate|drag crate|3.0
# multi drag|drag|1.8
# around screen|around screen|0.4
# single moves|2x select/drag|22.6
# position/move|position/move|6.4
# drag|select/drag|2.8
# select/draw|drag from robots|2.8
# around screen|drag from robots|1.0
# drag|drag|5.6
# select, ui, area|border|1.2
# drag|drag|0.0
# tap|group moves|11.5
# ui stop|draw "X"|4.0
# drag crate|drag crate|0.2
# select, draw square|use screen edges|24.0
# drag|drag|0.0
# tap robots|tap robot|0.2
# ui recolor|chop|1.0
# select/redirect|draw wall|2.0
# move corner|select/ui|1.0
# select/drag|select/drag|1.2
# to & across|border|8.2
# around screen|drag from robots|2.0
# drag|drag|3.0
# group moves|group moves|20.2
# select & around|corner|4.0
# voice, draw square in two parts|select, draw square|3.0
# position/move|drag crate|5.2
# draw spiral up away from screen|draw squiggle|1.0
# select/r pinch|chop|3.0
# select/doubletap whitespace|doubletap whitespace|2.0
# select/drag around|select/drag around|3.4
# single moves|2x select/move|3.6
# single moves|select/drag|15.8
# 2x select/move|drag|6.6
# drag robot|drag robot|0.0
# select/drag around|select/drag around|1.6
# select/drag|drag robot|2.0
# no command|group moves|19.6
# cut & drag|drag|2.4
# select/drag around|select/drag around|5.0
# select/drag|tap|2.6
# chop|chop|2.2
# select/ui|tap|7.8
# select/drag around|select/drag around|5.8
# voice|draw wall|8.4
# 2x select/move|2x select/move|3.0
# ccw lasso|5f scatter|1.2
# voice, move edge|corner|1.0
# ui/select/move crate|position/move|3.4
# drag offscreen|edge|3.0
# 2x select/move|drag|2.6
# to & ui|border|26.0
# single moves|drag robot|7.4
# drag|drag|0.0
# corner|corner|0.8
# select/5f scatter|select/4f scatter|2.6
# spiral on robot then off screen|pinch|0.8
# to & across|select, ui, path|2.2
# drag crate|drag crate|1.2
# partial drag around|select/drag around|4.6
# drag|2x select/drag|3.75
# drag crate|drag crate|0.8
# drag|2x select/drag|5.33333333333
# position/move|drag crate|13.6
# position/move|position/move|4.4
# 5f scatter|opening fists|0.4
# to & around|drag offscreen|1.4
# drag offscreen|drag|1.4
# corner|drag offscreen|2.0
# 5f scatter|draw "R"|1.2
# single moves|drag|2.0
# 2x select/tap|select/tap|19.0
# drag from robots|around screen|4.2
# sweep|select/draw|4.4
# drag|drag|0.8
# to & across|border|1.6
# ui, select|border|3.6
# bottom of screen|drag offscreen|1.0
# 5f scatter|select/drag around|4.33333333333
# select/tap|drag robot|11.0
# position/move|position/move|3.0
# to & around|to & around|2.4
# draw square|select, draw square|3.6
# draw two spirals |chop|1.4
# drag|2x select/move|4.5
# 3 loop lasso|chop|1.0
# select & around|edge|5.6
# drag robot|drag robot|2.4
# draw "P->A"|edge|10.8
# drag robot|select/drag|3.6
# drag from robots|around screen|0.8
# position/move|drag crate|6.0
# drag|drag|3.2
# drag back|tap robot|1.0
# tap robot|tap robot|0.0
# ui/object/target|position/move|9.0
# drag|drag|1.0
# cut|cut|2.4
# drag offscreen|corner|1.4
# 2x select/move|2x select/move|4.5
# draw squiggle|tap|1.2
# select/multi rev pinch|rev pinch|2.2
# drag crate|drag crate|0.6
# drag robot|drag robot|0.0
# 2x select/tap|drag|7.6
# border|around screen|0.6
# draw "C -> A"|drag crate|3.4
# lots of drags|drag|2.8
# cut|cut|0.0
# drag|drag|1.0
# position/move|position/move|8.8
# select & around|drag offscreen|3.2
# select/drag around|select/draw|2.6
# drag robot|drag robot|0.8
# multiple drag|drag|4.0
# drag|drag|0.0
# drag|drag|0.0
# select, to & around|to & around|18.0
# position/move|drag crate|6.8
# edge|corner|4.8
# drag|drag|1.6
# pinch|drag|1.0
# group moves|group moves|8.6
# 2x select/drag|select/drag|4.0
# drag crate|position/move|13.5
# position/move|position/move|2.6
# drag|drag|2.4
# drag robot|drag robot|0.0
# select & around|border|2.6
# select/drag|drag robot|2.0
# single moves|select/drag|11.6
# position/move|drag crate|5.0
# select/drag crate|drag crate|4.8
# group moves|partial drag around|2.4
# select/drag|drag|9.0
# tap robot|draw wall|2.8
# drag|around screen|5.0
# select & around|to & around|16.2
# drag robot|drag robot|0.2
# drag back|doubletap robot|1.0
# doubletap|tap|1.0
# drag crate|position/move|11.3333333333
# select/tap|select/tap|8.4
# cut|cut|0.2
# multi drag|drag|4.4
# drag robot|drag robot|1.6
# squiggle|squiggle|1.8
# cut/r pinch|drag|3.8
# drag|select/drag|1.8
# drag|drag|1.6
# no interaction|chop|2.0
# opening fists|squiggle|0.6
# position/move|drag crate|2.4
# position/move|drag crate|2.0
# select/drag|select/drag|1.8
# drag|drag|0.0
# select, ui, path|to & around|1.6
# draw "C->A"|position/move|25.2
# voice|drag from robots|1.0
# drag|drag|2.8
# 2x select/move|2x select/move|2.0
# border|border|2.6
# drag|drag|2.0
# drag|drag|2.6
# drag|2x select/move|3.2
# drag|drag|2.4
# tap robot|2x select/tap|9.0
# ui|squiggle|2.0
# no action|draw square|2.4
# drag|drag|0.8
# select/ui|select/drag|3.0
# select/tap|2x select/drag|2.0
# to & around|to & around|1.8
# move wall |drag back|0.8
# select/draw|select/draw|3.4
# draw squiggle|tap|3.6
# position/move|position/move|4.6
# 2x select/move|2x select/move|4.6
# cut|drag|2.0
# tap|tap|0.2
# drag|drag|0.0
# cut|cut|0.4
# sweep|sweep|2.8
# drag robot|drag robot|0.6
# drag|drag|0.2
# draw, draw "L"|select/draw|2.0
# single moves|around screen|9.6
# to & around|border|1.0
# drag|drag|3.2
# drag|drag|0.2
# drag robot|select/drag|2.0
# position/move|position/move|4.0
# 2x select/drag|2x select/drag|4.0
# drag crate|drag crate|0.4
# drag robot|drag robot|5.6
# draw square|select, draw square|16.0
# drag|drag|2.2
# cut|chop|4.2
# drag crate|position/move|7.25
# drag robot|drag robot|1.8
# drag|drag|1.2
# select/draw|ui/draw|7.2
# draw square as multiple lines|single moves|4.8
# drag from robots|select/pinch|1.8
# select/move offscreen|tap|2.8
# cut|cut|0.6
# drag|drag|5.8
# drag|sweep|1.4
# single moves|select/drag|18.2
# single moves|drag robot|7.2
# drag|drag|0.0
# select/rev pinch|select/use edge|2.0
# draw "SQ"|draw square|3.4
# cut|cut|0.0
# select/drag|2x select/drag|5.2
# position/move|position/move|4.6
# sweep|select/rev pinch|3.0
# voice, draw square|draw square|2.2
# corner|corner|14.0
# corner|bottom of screen|1.0
# voice|doubletap robot|1.8
# to & around|select, draw square|12.3333333333
# single moves|around screen|12.2
# to & around|to & around|12.6
# select/drag|drag|1.8
# pinch|pinch|0.6
# voice/chop|around screen|2.4
# 2x select/move|2x select/move|3.2
# drag back|draw wall|2.2
# voice|cut|1.0
# 2x select/drag|2x select/drag|3.5
# to & around|select, to & around|2.2
# select/drag|drag robot|1.6
# draw part of square|draw square|6.4
# voice|drag|2.0
# doubletap robot|tap robot|1.0
# select/drag around|border|2.0
# position/move|position/move|5.6
# draw, drag to line|select/draw|2.8
# ui mark|tap|1.0
# voice|squiggle|2.0
# doubletap each robot|doubletap robot|5.6
# drag robot|drag robot|3.0
# drag crate|drag crate|1.2
# single moves|single moves|7.0
# single moves|draw square|6.0
# tap|select/drag around|3.6
# drag|drag|0.0
# position/move|drag crate|1.8
# select/drag|drag|1.6
# to & around|select, to & around|1.8
# ui mark|spread/sweep|1.6
# drag robot|drag robot|6.2
# position/move|drag crate|3.0
# to & around|to & around|1.4
# select, formation ui|draw square|3.6
# tap|chop|2.0
# 2x select/move|2x select/move|3.2
# 4f scatter|squiggle|0.8
# drag|drag|2.0
# to area, not around|border|6.8
# 2x select/drag|2x select/drag|1.8
# edge|offscreen garbage bin|2.8
# sweep|drag robot|8.2
# select/ui|tap|2.0
# border|corner|1.2
# select/drag|select/drag|3.2
# single moves|drag|3.2
# select/drag|drag|3.8
# drag|drag|2.8
# position/move|drag crate|1.8
# 5f scatter|5f scatter|0.4
# chop|spread 2f tap|4.6
# squiggle|squiggle|1.2
# patrol ui|5f scatter|1.0
# position/move|drag crate|3.2
# draw square|draw square|0.6
# tap/tap|drag crate|2.0
# drag|drag|0.8
# multi sweep|drag|2.2
# sweep|pinch|2.0
# drag from robots|select/draw|1.6
# drag|drag|0.4
# drag|drag|3.0
# position/move|position/move|4.8
# select/drag|drag robot|1.0
# drag robot|drag robot|10.6666666667
# multiple push|drag|4.8
# no interaction|drag offscreen|2.0
# select, draw "X"|drag|3.8
# voice|drag from robots|2.0
# tap|select/drag|6.33333333333
# tap, ui stop|tap robot|4.0
# multi drag partway around|select/drag around|7.6
# tap|select/ui|1.75
# pinch|pinch|0.2
# drag crate|drag crate|2.2
# select/drag|drag|5.2
# select/drag around|tap|2.6
# border|drag from robots|2.2
# cut & move|2x select/move|5.4
# around screen|select/drag around|5.25
# drag robot|drag robot|8.0
# single moves|2x select/move|14.0
# 2x select/move|2x select/move|7.8
# drag offscreen|select/drag|1.4
# 2x select/move|2x select/move|1.8
# edge|drag offscreen|0.4
# position/move|position/move|23.0
# ui delete|drag|6.0
# select/drag around|tap|2.6
# drag crate|drag crate|2.4
# select/rev pinch|rev pinch|2.6
# organize positions|select/drag around|18.6
# draw square|draw square|0.8
# around screen|around screen|0.4
# drag from robots|around screen|3.6
# drag|drag|1.2
# drag|2x select/move|5.0
# drag|drag|0.6
# drag back|doubletap robot|0.6
# drag|drag|0.0
# rev pinch|squiggle|1.0
# select/draw|draw line|2.8
# 2x select/move|2x select/move|3.8
# drag|drag|0.0
# ui/object/target|drag crate|1.6
# sweep|pinch|6.4
# 5f scatter|group moves|8.0
# select/drag|select/drag|4.8
# chop|drag back|0.8
# single moves|2x select/drag|14.0
# select/ui|drag|1.8
# to & around|to & around|2.2
# drag|drag|2.6
# single moves|2x select/move|53.6
# position/move|position/move|1.6
# select & tap A|edge|3.8
# tap|tap|1.6
# no interaction|drag|7.2
# chop & move|2x select/move|6.0
# drag crate|drag crate|4.0
# drag|drag|0.0
# draw "P" in a circle|select/drag around|4.4
# around screen|border|0.8
# select/drag|select/drag|1.6
# drag|select/drag|4.66666666667
# drag|drag|0.0
# drag|drag|0.0
# multi drag partway around|select/drag around|13.0
# set waypoints|to & around|7.6
# drag from robots|select/rev pinch|4.0
# position/move|position/move|9.0
# 2x select/drag|2x select/drag|5.0
# drag robots back|drag back|0.4
# draw "X"|draw squiggle|2.0
# rev pinch|drag|3.4
# 2h drag|drag|1.6
# tap robot|tap robot|0.0
# drag|drag|1.2
# patrol ui|ui/draw|8.4
# position/move|drag crate|0.8
# 2x select/drag|select/r pinch|4.4
# tap robot|tap robot|1.4
# drag|2x select/move|6.33333333333
# to & squiggle over|border|2.4
# voice|tap robot|1.0
# draw line|around screen|4.25
# drag|drag|0.0
# 2x select/move|2x select/move|4.0
# select/move|pinch|1.0
# select/drag around|drag off edge|2.2
# drag|drag|0.0
# draw square|select, draw square|9.25
# tap robot|draw "X"|2.5
# drag|drag|1.4
# single moves|draw square|15.6
# single moves|2x select/move|16.4
# to & around|draw square|3.4
# drag offscreen|corner|3.75
# draw square|draw square|2.4
# select, tap targets|drag|3.8
# drag crate|drag crate|1.4
# drag|pinch|1.4
# ui, border|border|9.5
# select, draw square|select, draw square|6.0
# drag|2x select/move|6.0
# around screen|drag from robots|6.0
# cut & drag|2x select/move|3.6
# select/drag|select/tap|15.0
# 2 tap|drag|3.4
# single moves|2x select/move|46.6
# drag offscreen|to & around|0.8
# pinch|pinch|0.4
# around screen|around screen|0.6
# pinch|pinch|0.0
# r pinch/drag|drag|3.0
# draw line|drag from robots|1.4
# position/move|position/move|2.6
# drag|drag|0.0
# border|select, to & around|9.0
# drag|chop|2.2
# position/move|position/move|18.8
# multi drag|select/drag around|1.4
# drag crate|drag crate|2.0
# single moves|single moves|28.8
# cut|select/drag|8.0
# drag|drag|0.0
# draw wall|doubletap robot|3.0
# position/move|position/move|8.6
# single moves|around screen|17.4
# to, select A|corner|5.0
# position/move|position/move|4.8
# select/draw|select/rev pinch|1.8
# select/drag|2x select/drag|9.6
# drag crate|position/move|2.2
# corner|leave behind|7.0
# drag|drag|0.0
# drag robot|drag robot|0.0
# sweep|sweep|0.8
# draw wall|drag back|2.4
# drag|2x select/move|7.2
# draw square|draw square|0.8
# draw "X"|select/drag around|1.6
# drag robot|drag robot|0.0
# to & around|bottom of screen|1.6
# pinch|pinch|0.8
# drag robot|drag robot|0.8
# position/move|position/move|26.4
# drag|drag|1.2
# select & to A|to & around|3.2
# drag|drag|1.2
# drag off edge|select/ui|2.66666666667
# doubletap robot|doubletap robot|0.6
# select, formation ui|draw square|1.6
# position/move|position/move|5.0
# draw line|select/draw|3.4
# drag|drag|0.4
# sweep|drag|2.4
# select/4f scatter|border|3.6
# draw line|around screen|0.6
# drag robot|drag robot|6.6
# tap|leave behind|3.0
# single moves|tap|34.2
# drag robot|drag robot|0.2
# to & around|border|9.0
# corner|corner|1.8
# corner|corner|9.2
# select/drag|drag|1.4
# select/draw|around screen|0.2
# draw line|drag from robots|3.4
# select/tap|drag robot|1.6
# draw square|draw square|0.6
# around screen|around screen|9.4
# drag|drag|2.0
# position/move|position/move|19.0
# pinch|2x select/tap|7.0
# cut|chop|1.6
# drag|chop|1.8
# group moves|select/drag around|12.6
# ui remove|corner|1.0
# single moves|draw square|9.0
# drag|drag|0.8
# drag|drag|3.0
# drag|2x select/move|5.0
# split & drag|drag|3.6
# drag|drag|1.2
# 2x select/move|2x select/move|9.6
# position/move|position/move|6.2
# select/move|drag|1.4
# position/no move|position/move|4.8
# drag|drag|0.4
# drag|drag|2.0
# drag|drag|0.8
# drag robot|drag robot|1.2
# sweep|drag|0.6
# drag|drag|0.0
# drag|drag|0.0
# drag crate|position/move|7.0
# drag|drag|0.0
# drag|drag|0.8
# sweep|drag|0.8
# select/drag|select/drag|5.0
# multi drag robot|drag robot|0.4
# squiggle|group moves|6.0
# drag crate|drag crate|0.8
# border|border|3.2
# draw "R"|border|0.4
# select robots|draw "X"|5.0
# border|select/drag around|4.5
# drag crate|drag crate|2.4
# select/drag crate|position/move|7.0
# tap & draw "0.5"|drag|9.8

# %%
#Get the counts of strings for each strategy
strByStrat = {}
for t in new_task_strs:
    if t[4] not in strByStrat.keys():
        strByStrat[t[4]] = {}
    if t[3] in strByStrat[t[4]].keys():
        strByStrat[t[4]][t[3]] += 1
    else:
        strByStrat[t[4]][t[3]] = 1

# %%
for strategy in strByStrat.keys():
    print strategy
    print "="*len(strategy)
    for k, v in sorted(strByStrat[strategy].iteritems(), key= lambda (k,v): (v,k)):
        print "{}\t{}".format(v, k)
    print ""
# Out:
# select/rev pinch
# ================
# 3	BrRr
#
# ui
# ==
# 1
#
# draw, drag to line
# ==================
# 1	WwWrw
#
# ui, select
# ==========
# 1	DwLr
#
# flat hand robots
# ================
# 1	OrTr
#
# 2x select/move
# ==============
# 1	BrBrDrDr
# 1	BrBrDraBrDbw
# 1	BrBrDrbBrDra
# 1	BrDraBrDra
# 1	BrTbBrDrbBrDra
# 1	BrTwDbwBrTwTa
# 1	LrDrDrbLrDrbLrTaDra
# 1	LrDrbDaLrDrb
# 1	LrDrbLrDr
# 1	LrTaLrTb
# 1	LrWraLrWrb
# 1	LrWrbLrWra
# 1	RrDrb
# 1	TrWrbTrWra
# 1	TwTwWraWrb
# 2	BrDrbBrDra
# 2	LrDrbLrDra
# 3	Vrab
# 5	LrDraLrDrb
#
# corner
# ======
# 1	2rWr
# 1	BrTrDr
# 1	LrDr
# 1	LrDrLrDrTrLrDr
# 1	TrDrT_Or3r
# 1	TrTwTrTrTwTrTrwLrDr
# 1	Wr
# 3	Dr
#
# move away
# =========
# 1	DrOr
# 1	TrTwTwTw
#
# select/tap
# ==========
# 1	BrBrBrTrwTwBr
# 1	BrTa
# 1	BrTw
# 1	LrTa
# 1	LrTr
# 1	LrTw
#
# chop & move
# ===========
# 1	OrOrOr
#
# lasso
# =====
# 3	Lr
#
# cut/drag
# ========
# 1	WrDrWrDrTrTrTrWrWrTr
#
# ui select
# =========
# 1
#
# select/drag crate
# =================
# 1	2cWca
# 1	2rDa
# 1	WcDcaTa
#
# draw "X"
# ========
# 1	DrDr
# 1	LrDrDr
# 1	Wr
# 1	WrWr
#
# rasied hand pull back
# =====================
# 1	Ow
#
# position, no move
# =================
# 1	BrDrcTc
# 1	DrcDrcDrcDrcDrc
#
# r pinch/drag
# ============
# 1	Orab
#
# multi pinch
# ===========
# 1	PrPrPrPrPr
#
# 2h drag
# =======
# 1	DraDrbDraDrb
# 1	DrbDra
#
# select/redirect
# ===============
# 1	BrTw
# 1	LrDr
#
# multiple push
# =============
# 1	OrObOrOa
#
# offscreen garbage bin
# =====================
# 1	Wrw
#
# select robots
# =============
# 1	Br
#
# draw "P->A"
# ===========
# 1	WwWwWwWwWwWw
#
# select/r pinch
# ==============
# 1	LrRr
# 1	LrWrRr
#
# select/4f scatter
# =================
# 1	2rOr
# 1	BrOrOr
#
# select/use edge
# ===============
# 1	BrTrw
#
# other robots push offscreen
# ===========================
# 1	TrwOrwWrwDrDrw
#
# 3 loop lasso
# ============
# 1	Lr
#
# ui mark
# =======
# 1
# 1	Br
# 1	RrRr
# 1	Tr
#
# multi select/drag partway around
# ================================
# 1	LrDrwW_LrDrwW_D_DrDw
#
# select, tap targets
# ===================
# 1	BrTaTb
#
# 5f scatter
# ==========
# 7	Or
#
# tap whitespace
# ==============
# 1	Tw
#
# select/move
# ===========
# 1	LrDr
# 1	Vr
#
# pinch
# =====
# 2	Rr
# 7	Pr
#
# cut & drag
# ==========
# 1	WrWraLrWr
# 2	WrDraDrb
#
# voice, move edge
# ================
# 1	Vr
#
# draw part of square
# ===================
# 1	WrwWrwTrw
#
# draw "10" in box A
# ==================
# 1	WaWa
#
# around screen
# =============
# 1	DrDw
# 1	DrOrDrw
# 1	DrwTrTwRw
# 1	OwOwDrw
# 1	Ww2w2w2wTwTw
# 8	Drw
#
# select & to A
# =============
# 1	BrPrDra
#
# draw spiral up away from screen
# ===============================
# 1	Wr
#
# select & tap A
# ==============
# 1	Dr2aDra
#
# cut & move
# ==========
# 1	WrWrbWra
#
# move fist in circle over, tap
# =============================
# 1	OrTr
#
# 2x select/drag
# ==============
# 1	BrBrDrDr
# 1	BrBrDrDrBrBrTr
# 1	BrBrDraBrDrb
# 1	BrDr
# 1	BrDraBrDrb
# 1	LrDraLrDra
# 1	LrDraW_LrDrbW_
# 1	LrDrbLrDrb
# 1	LrLrDrDr
# 1	LrWraLrWrb
# 1	LrWrwLrWrwLrWr
# 1	WrWr
# 3	LrDrLrDr
# 4	LrDraLrDrb
#
# partial drag around
# ===================
# 1	DrDr
# 1	Dw
# 1	DwDrwDw
#
# select, draw "X"
# ================
# 1	TrTrWr
#
# tap robot
# =========
# 1	2rDr2r
# 1	Tr2r
# 9	Tr
#
# voice/draw
# ==========
# 1	V_Ww
# 1	VrDrwD_
#
# voice, draw square in two parts
# ===============================
# 1	VrWwWw
#
# multi drag
# ==========
# 1	Wr
# 1	WrWr
# 1	WrWrWrWw
# 1	Wra
#
# select/draw "X"
# ===============
# 1	LrWrWr
#
# voice, draw square
# ==================
# 1	V_Wr
# 1	V_Ww
#
# select, formation ui
# ====================
# 1
# 1	Brw
# 1	OrOrWw
#
# select/drag around
# ==================
# 1	2rDw
# 1	3rDrw
# 1	BrBrDrwDw
# 1	BrDrDr
# 1	BrDw
# 1	BrWw
# 1	LrDr
# 1	LrTwWwWw
# 1	LrWwDw
# 1	Orw
# 1	TrWr
# 1	TrWrW_
# 1	Wr
#
# tap, ui stop
# ============
# 1	TrTwTw
#
# drag robot
# ==========
# 1	DrDrDraLrDra
# 1	DrDraTrDrDraTa
# 1	DrDrwDa
# 1	DraOraOraOraOra
# 1	DraTa
# 1	DraTaTrTaDrDra
# 1	DraTrTa
# 1	DraTrTaDrDrDra
# 1	DrwDrwDra
# 1	TaWrTa
# 1	WrTrWra
# 1	WraTa
# 1	WraWraOraWra
# 2	DraDra
# 5	Wra
# 13	Dra
#
# draw "R"
# ========
# 1	Ww
#
# drag crate
# ==========
# 1	DcaOr
# 1	Drca
# 1	OaOaOc
# 1	Oc
# 1	WcDcaTa
# 1	Wca2r
# 1	WcaWrca
# 1	WwWwWrwWc
# 2	DcaW_
# 5	Wca
# 11	Dca
#
# tap, move corner
# ================
# 1	TrTrTw
#
# cut
# ===
# 1	DrDrD_
# 1	Wrw
# 1	Ww
# 1	WwWw
# 8	Wr
#
# draw squiggle
# =============
# 1	Dr
# 1	Or
# 1	WrTrWr
#
# draw two spirals
# =================
# 1	Ow
#
# select/ui/draw
# ==============
# 1	BrBrWwWw
# 1	BrWrTwWwW_
#
# 2x select/tap
# =============
# 1	BrTaBrTbTaTb
# 1	BrTbTbBrTaTb
# 1	LrLrLrDr2wLrDr2wTw3wTw
#
# draw "C -> A"
# =============
# 1
#
# select/ui
# =========
# 1	BrBr
# 1	BrTrTr
# 1	BrTrTrw
# 1	LrTr
# 1	Tr
# 1	Tr2r2wTw2rWw
# 2	Br
#
# organize positions
# ==================
# 1	LrPrDrwLrDrwLrPrPrDrwLrDrw
#
# multi drag partway around
# =========================
# 1	DrDrDrDrDrDr
# 1	WrWrWrWwWwWwWwWw
#
# ui recolor
# ==========
# 1	Tr
#
# ui/select/move crate
# ====================
# 1	BrLcDca
#
# voice/chop
# ==========
# 1	V_Ow
#
# chop
# ====
# 1	OrOr
# 2	Or
#
# opening fists
# =============
# 1	Or
#
# multi drag back
# ===============
# 1	Wr
#
# select/5f scatter
# =================
# 1	BrOr
# 1	LrTrOr
#
# select & around
# ===============
# 1	2rD_Dra
# 1	2rDa
# 1	BrWa
# 1	DaTrTrTrTrTrTrTrTrTrTrDa
# 1	WrWaWrWa
#
# select/pinch
# ============
# 1	LrPr
#
# cut & push
# ==========
# 1	DrOrOrOrOr
#
# 2 tap
# =====
# 1	Ta
#
# draw circle whitespace
# ======================
# 1	Ww
#
# draw "C->A"
# ===========
# 1	WawWwWwWwWwWwTwTaTaWcWcTcWwWwTw
#
# select/doubletap whitespace
# ===========================
# 1	Lr2w
#
# select/drag
# ===========
# 1	BrDr
# 1	BrDrDa
# 1	BrDrDra
# 1	BrDw
# 1	BrWr
# 1	BrWrWr
# 1	Dr
# 1	DrBrTwTa
# 1	DrDra
# 1	DrDraDraTrLrDraLrDraTa
# 1	DrTa
# 1	DraDrDr
# 1	DraDraDrDrDraOr
# 1	LrDraDraDraLrDraDra
# 1	TrLrTrDra
# 1	TrTw2rTw2rTw
# 1	TrWrTrDrw
# 1	TrWraTrWrb
# 2	LrDr
# 2	LrDra
# 2	LrWra
# 3	BrDra
#
# drag offscreen
# ==============
# 1	Dw
# 1	LrDrw
# 1	Or
# 1	TrOr
# 1	TwDrw
# 1	Wr
# 1	WrDrw
# 3	Drw
#
# sweep
# =====
# 1	Or
# 1	OrOrOrOr
# 1	OrOrOrWr
# 1	OrOra
# 1	OrbOra
# 1	OrwOw
# 1	Ow
# 2	OrOrOr
# 2	Orw
# 3	OrOr
#
# to, select A
# ============
# 1	Ora
#
# sweep around screen
# ===================
# 1	OrOw
#
# tap & draw "0.5"
# ================
# 1	2a3aWwTwWwWw
#
# draw line behind robots
# =======================
# 1	Tw
#
# select/draw
# ===========
# 1	2rWw
# 1	BrWw
# 1	Drw
# 1	LrWw3w
# 1	LrWwDrW_WwWr
# 1	Or
#
# draw wall
# =========
# 1	DrOr
# 1	Wrab
# 1	Ww2w
# 1	WwT_
# 2	Ww
#
# ui/object/target
# ================
# 1	TcTa
# 1	TwTrwTwV_LcDca
#
# select, ui, area
# ================
# 1	BrDa
#
# single moves
# ============
# 1
# 1	DrDrDrDrDrDrDrDrDr
# 1	DrDrDrDrDrOrDrDrWw
# 1	DrDrDrDrDraDrV_Va
# 1	DrDrDrLrPrPrDrwLrPrPrDrLrPrPrDrLrPrPrDrDw
# 1	DrDraDraDraDraDraDraDraDraDraDraDraDrbDrbDrbDrbDrbDrbDrbDrbDrb
# 1	DraDraDraDraDrTaTa
# 1	DraDraDraDraDraDraDraDra
# 1	DraDraDraDraDraDraDraDraDra
# 1	DraDraDraDraDraDraDraDraDraDra
# 1	DraDraDraDraDraDraDraDraDraDraDraDrbDrbDrbDrbDrbDrbDrbDrbDrbDrbDrb
# 1	DraDraDraDraDraDraDrbDraDrbDraDrbDraDrbDraDrbDraDrbDra
# 1	DraDraDraDraDraDrbDrbDrbDrbDrb
# 1	DraDraDraDraDrbDrbDrbDrbDrb
# 1	DraDraDraDrb
# 1	DraDraTrDra3rDraDra2w2w2rDraDra2r3rTrTrDrwDraDra3rDraDra
# 1	DrbDrbDrbDrbDraDrbDrDrDr
# 1	DrwDrwDrwDrwDrwDrw
# 1	TrTwTrTwTrTwTrTwTrTrwTrTw
# 1	TrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTw
# 1	TrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTw
# 1	TrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTwTrTw
# 1	Wr
# 1	WrWr
# 1	WwWwWwWw
# 2	DrDrDrDrDrDrDr
# 2	DrDrDrDrDrDrDrDr
# 2	DrDrDrDrDrDrDrDrDrDr
# 2	WrWrWrWrWrWr
#
# draw "SQ"
# =========
# 1	WrWrTr
#
# 4f scatter
# ==========
# 1	Or
#
# select, draw square
# ===================
# 1	2rTwOr
# 1	BrWw
# 1	LrTwWwTwWw
# 1	LrWw3_
# 1	TwWw
#
# select/multi rev pinch
# ======================
# 1	LrRr
#
# cut/r pinch
# ===========
# 1	2rWrRr
#
# position/move
# =============
# 1	2cDrca
# 1	2rTwDa
# 1	2rWwWwDc
# 1	B_TcDcaDcaDa
# 1	BrDrcDcDcaTaDcbDcaDcaDa
# 1	BrDrcTcDca
# 1	BrT_OrwOrwTa
# 1	DcwDca
# 1	DrcDcDrcDca
# 1	DrcDcaDrca
# 1	DrcDrcDca
# 1	DrcDrcDcaDa
# 1	DrcDrcDcaDrcDrcDa
# 1	DrcDrcDrcDrcTcTc2wDrcDrcDrcDrcTa
# 1	DrcDrcDrcDrca
# 1	DrcV_2cDca
# 1	LrDrcDca
# 1	LrDrcDrca
# 1	LrDrcLrLrWc3cwLrDrc3cwWcTcLcDca
# 1	LrTrTcTa
# 1	LrWc3cwLrWc3cwTcLcDca
# 1	Or
# 1	OrDrcDcaDaDcDa
# 1	OrOr
# 1	OrOrOrDca
# 1	OrwDcDcDcDca
# 1	TawOwDrcDcaDcDa
# 1	TcDrca
# 1	TcTcTcDcaDcDcwDaw
# 1	TrT_OrcbTa
# 1	TrTcTcTrTcTcTcTrcTcTrTcTrTcTrTcTa
# 1	TrWrca
# 1	V_DrcDca
# 1	WcDca
# 1	WcTaDca
# 1	WrWrWrc
# 1	WraWcaWcaWcaWraWrWrWrWca
# 1	Wrca
# 2	Vrca
# 2	WrWr
# 3	DrcDca
# 3	Drca
#
# multi sweep
# ===========
# 1	OrOr
#
# set waypoints
# =============
# 1	DrTaTaTaTaTr
# 1	Tr2aTaTaTaTaTaTa
#
# select/move offscreen
# =====================
# 1	TrWrw
#
# ui remove
# =========
# 1
# 1	2r
# 1	TrBrTwTw
#
# spread 2f tap
# =============
# 1	Or
#
# tap crate, robot, A
# ===================
# 1	Tc2rTa
#
# split & drag
# ============
# 1	OrwOrOr
#
# patrol ui
# =========
# 1	Br
# 1	Dw
# 1	TrT_T_TrTrTr
# 1	TwWw
#
# to area, not around
# ===================
# 1	DraDraDr
#
# tap/tap
# =======
# 1	TcTa
#
# draw, draw "L"
# ==============
# 1	WwWw
#
# multi drag robot
# ================
# 1	Wra
#
# fist circle, move edge
# ======================
# 1	OrOrOr
#
# position/no move
# ================
# 1	LrTwTw
#
# no action
# =========
# 1
#
# ui/waypoint
# ===========
# 1	BrTc2aTcTa
# 1	T_TaTr
#
# draw square
# ===========
# 1	2rWw
# 1	Drw
# 1	TrWrw
# 1	TrwWrwTrwWrwWrwTrw
# 1	Ww2rwWw
# 2	Wr
# 3	Ww
# 4	Wrw
#
# drag back
# =========
# 1	DrWw
# 1	Dra
# 1	Or
# 1	Wr
# 2	Dr
#
# drag off edge
# =============
# 1	Drw
#
# hold, ui remove
# ===============
# 1
#
# select, to & around
# ===================
# 1	BrDra
# 1	LrWaWa
#
# multiple drag
# =============
# 1	DrbDaDaDb
# 1	DrbDra
#
# drag from robots
# ================
# 1	Dr
# 1	DrDrwDrD_
# 1	Drw2_
# 1	Orw
# 1	WrWr
# 1	Wrw
#
# multiple select and draw parts
# ==============================
# 1	WwWwLrLrWrwWrwWrwWrwTwDwDwDwDwWrwWrwWrw
#
# select/waypoint
# ===============
# 1	LrTwTwTwTwTwTwTwWwTwWwTwTwTwTwTwTw
#
# doubletap each robot
# ====================
# 1	2r2r2r2r
#
# to & squiggle over
# ==================
# 1	Wra
#
# spread/sweep
# ============
# 1	Or
# 1	OrOr
# 1	OrOrOr
#
# draw square as multiple lines
# =============================
# 1	WrWrWrWr
#
# voice
# =====
# 1	V_OwOwOwOw
# 1	V_Pr
# 1	V_Wr
# 1	Va
# 2	V_
# 2	Vrw
# 3	Vr
#
# ui stop
# =======
# 1
#
# ui/draw
# =======
# 1	DrTwTwTwWw
#
# draw "P" in a circle
# ====================
# 1	WwTwWw
#
# tap
# ===
# 1	2r2rTw
# 1	Dw
# 1	Tr2r
# 1	Tr3rTr
# 2	TrTr
# 6	Tr
#
# ccw lasso
# =========
# 1	Lr
#
# drag robots back
# ================
# 1	Dr
# 1	OrO_
#
# to & around
# ===========
# 1	BrDra
# 1	DrDrDrDrDrwDrwDrwDrwDa
# 1	DraDa
# 1	DraDra
# 1	DraRa
# 1	DraVa
# 1	LrDraW_W_DraDraWraDra
# 1	LrLrDrDrwDraDr
# 1	OrDraDraDra
# 1	Orw
# 1	TrWra
# 7	Dra
#
# ui delete
# =========
# 1	2r2wWrwTw
# 1	Rr
# 1	Tr
#
# leave behind
# ============
# 1	BrDr
# 1	Drw
#
# lots of drags
# =============
# 1	WrWr
#
# border
# ======
# 1	Da
# 1	DaDa
# 1	DaDaOr
# 1	DaDra
# 1	Drw
# 1	DwTw
# 2	Wa
# 4	Dw
# 4	Ww
#
# no interaction
# ==============
# 3
#
# doubletap
# =========
# 1	3r
# 2	2r
#
# squiggle
# ========
# 1	Drw
# 1	Ww
# 2	Dr
#
# select & path
# =============
# 1	LrWaDa
#
# group moves
# ===========
# 1	2wDr
# 1	DrDrDrDrDrDrDrDr
# 1	DrDrDrDrDrDrDrDrDr
# 1	DrDrW_DrW_DrW_DrW_DrW_DrW_DrW_DrW_
# 1	DrDrwDrDrDrDrDrDrDr
# 1	LrLrLrLrDrDrDrDr
# 1	WrWrWwWrWrWrWrWr
#
# move corner
# ===========
# 1	Vr
#
# move wall
# ==========
# 1	Dr
#
# tap crate tap a
# ===============
# 1	TcTa
#
# ui, border
# ==========
# 1
#
# 4f spread
# =========
# 1	DwOwOw
#
# doubletap robot
# ===============
# 3	2r
#
# drag
# ====
# 1
# 1	DrDrDr
# 1	DrDrwDa
# 1	DrT_
# 1	DraDra
# 1	DraTa
# 1	Drb
# 1	DrbDbDra
# 1	DrbDraDrb
# 1	DrbDrbDraDra
# 1	DrwDrwDrw
# 1	TrWra
# 1	WraWra
# 1	Wrab
# 2	DraDrbDraDrb
# 2	Wr
# 2	WrWr
# 3	DraDr
# 3	Or
# 4	OrOr
# 4	WraWrb
# 4	WrbWra
# 6	Dr
# 6	DrDr
# 6	Wra
# 14	Dra
# 14	DrbDra
# 25	DraDrb
#
# to & ui
# =======
# 1	DraTrTaTrTaTrTraTrTraTrTraTrDaTw
#
# rev pinch
# =========
# 7	Rr
#
# multiple sweeps
# ===============
# 1	OrbOrbOra
#
# select, ui, path
# ================
# 1	BrWa
#
# voice
# ======
# 1	2r2rTrTr
# 1	V_
#
# draw line
# =========
# 1	DwDrw
# 1	Ww
# 1	WwTwWw
# 2	Dr
#
# spiral on robot then off screen
# ===============================
# 1	Wr
#
# bottom of screen
# ================
# 1	Wr
#
# no command
# ==========
# 1	DwDwDwDwDwTrTrTrTrTrTrTrTr
#
# to & across
# ===========
# 1	OrOa
# 1	Vra
# 1	WrWrWrWraWr
#
# doubletap whitespace
# ====================
# 2	2w
#
# use screen edges
# ================
# 1	BrwTwLwTwTwTwTwBrwD_D_DwLwDw
#
# edge
# ====
# 1	LrDrw
# 1	OrOrDrw
# 1	Wr
#
# push
# ====
# 1	OrOr
#
# voice, no interaction
# =====================
# 1	Vr
#
# tap robots
# ==========
# 1	Tr
#
# tap/ui
# ======
# 1	TrwOr

# %%
import re

def condenseString(inStr):
    #Replace "B" (box select), and "L" (lasso select) with "S" (general select)
    inStr = inStr.replace("B", "S")
    inStr = inStr.replace("L", "S")
    #Taps, doubletaps, tripletaps on robots or crate are selections too
    inStr = inStr.replace("Tr", "Sr")
    inStr = inStr.replace("2r", "Sr")
    inStr = inStr.replace("3r", "Sr")
    inStr = inStr.replace("Tc", "Sc")
    inStr = inStr.replace("2c", "Sc")
    inStr = inStr.replace("3c", "Sc")
    #Multiple selections in a row are just the last selection
    inStr = re.sub(r"S([rawcb_]+)(S\1)*", r"S\1", inStr)
    return inStr

print condenseString("DrDraDraTrLrDraLrDraTa")
print condenseString("TrTw2rTw2rTw")
print condenseString("BrBrDrDrBrBrTr")
print condenseString("BrBrDrwDw")
# Out:
# DrDraDraSrDraSrDraTa
# SrTwSrTwSrTw
# SrDrDrSr
# SrDrwDw

# %%
print new_task_strs[0]
# Out:
# (u'1', u'13', 'crate_dispersed', '2cDrca', 'position/move')

# %%
condensed = []
for t in new_task_strs:
    condensed.append((t[0], t[1], t[2], t[3], condenseString(t[3]), t[4]))

# %%
#Get the counts of strings for each strategy
strByStrat = {}
for t in condensed:
    if t[5] not in strByStrat.keys():
        strByStrat[t[5]] = {}
    if t[4] in strByStrat[t[5]].keys():
        strByStrat[t[5]][t[4]] += 1
    else:
        strByStrat[t[5]][t[4]] = 1

# %%
for strategy in strByStrat.keys():
    print strategy
    print "="*len(strategy)
    for k, v in sorted(strByStrat[strategy].iteritems(), key= lambda (k,v): (v,k)):
        print "{}\t{}".format(v, k)
    print ""
# Out:
# select/rev pinch
# ================
# 3	SrRr
#
# ui
# ==
# 1
#
# draw, drag to line
# ==================
# 1	WwWrw
#
# ui, select
# ==========
# 1	DwSr
#
# flat hand robots
# ================
# 1	OrSr
#
# 2x select/move
# ==============
# 1	RrDrb
# 1	SrDrDr
# 1	SrDrDrbSrDrbSrTaDra
# 1	SrDraSrDbw
# 1	SrDraSrDra
# 1	SrDrbDaSrDrb
# 1	SrDrbSrDr
# 1	SrTaSrTb
# 1	SrTbSrDrbSrDra
# 1	SrTwDbwSrTwTa
# 1	SrWraSrWrb
# 1	TwTwWraWrb
# 2	SrWrbSrWra
# 3	Vrab
# 5	SrDraSrDrb
# 5	SrDrbSrDra
#
# corner
# ======
# 1	SrDrSrDrSrDr
# 1	SrDrT_OrSr
# 1	SrTwSrTwSrwSrDr
# 1	SrWr
# 1	Wr
# 2	SrDr
# 3	Dr
#
# move away
# =========
# 1	DrOr
# 1	SrTwTwTw
#
# select/tap
# ==========
# 1	Sr
# 1	SrwTwSr
# 2	SrTa
# 2	SrTw
#
# chop & move
# ===========
# 1	OrOrOr
#
# lasso
# =====
# 3	Sr
#
# cut/drag
# ========
# 1	WrDrWrDrSrWrWrSr
#
# ui select
# =========
# 1
#
# select/drag crate
# =================
# 1	ScWca
# 1	SrDa
# 1	WcDcaTa
#
# draw "X"
# ========
# 1	DrDr
# 1	SrDrDr
# 1	Wr
# 1	WrWr
#
# rasied hand pull back
# =====================
# 1	Ow
#
# position, no move
# =================
# 1	DrcDrcDrcDrcDrc
# 1	SrDrcSc
#
# r pinch/drag
# ============
# 1	Orab
#
# multi pinch
# ===========
# 1	PrPrPrPrPr
#
# 2h drag
# =======
# 1	DraDrbDraDrb
# 1	DrbDra
#
# select/redirect
# ===============
# 1	SrDr
# 1	SrTw
#
# multiple push
# =============
# 1	OrObOrOa
#
# offscreen garbage bin
# =====================
# 1	Wrw
#
# select robots
# =============
# 1	Sr
#
# draw "P->A"
# ===========
# 1	WwWwWwWwWwWw
#
# select/r pinch
# ==============
# 1	SrRr
# 1	SrWrRr
#
# select/4f scatter
# =================
# 1	SrOr
# 1	SrOrOr
#
# select/use edge
# ===============
# 1	Srw
#
# other robots push offscreen
# ===========================
# 1	SrwOrwWrwDrDrw
#
# 3 loop lasso
# ============
# 1	Sr
#
# ui mark
# =======
# 1
# 1	RrRr
# 2	Sr
#
# multi select/drag partway around
# ================================
# 1	SrDrwW_SrDrwW_D_DrDw
#
# select, tap targets
# ===================
# 1	SrTaTb
#
# 5f scatter
# ==========
# 7	Or
#
# tap whitespace
# ==============
# 1	Tw
#
# select/move
# ===========
# 1	SrDr
# 1	Vr
#
# pinch
# =====
# 2	Rr
# 7	Pr
#
# cut & drag
# ==========
# 1	WrWraSrWr
# 2	WrDraDrb
#
# voice, move edge
# ================
# 1	Vr
#
# draw part of square
# ===================
# 1	WrwWrwSrw
#
# draw "10" in box A
# ==================
# 1	WaWa
#
# around screen
# =============
# 1	DrDw
# 1	DrOrDrw
# 1	DrwSrTwRw
# 1	OwOwDrw
# 1	Ww2w2w2wTwTw
# 8	Drw
#
# select & to A
# =============
# 1	SrPrDra
#
# draw spiral up away from screen
# ===============================
# 1	Wr
#
# select & tap A
# ==============
# 1	Dr2aDra
#
# cut & move
# ==========
# 1	WrWrbWra
#
# move fist in circle over, tap
# =============================
# 1	OrSr
#
# 2x select/drag
# ==============
# 1	SrDr
# 1	SrDrDrSr
# 1	SrDraSrDra
# 1	SrDraW_SrDrbW_
# 1	SrDrbSrDrb
# 1	SrWraSrWrb
# 1	SrWrwSrWrwSrWr
# 1	WrWr
# 2	SrDrDr
# 3	SrDrSrDr
# 6	SrDraSrDrb
#
# partial drag around
# ===================
# 1	DrDr
# 1	Dw
# 1	DwDrwDw
#
# select, draw "X"
# ================
# 1	SrWr
#
# tap robot
# =========
# 1	SrDrSr
# 10	Sr
#
# voice/draw
# ==========
# 1	V_Ww
# 1	VrDrwD_
#
# voice, draw square in two parts
# ===============================
# 1	VrWwWw
#
# multi drag
# ==========
# 1	Wr
# 1	WrWr
# 1	WrWrWrWw
# 1	Wra
#
# select/draw "X"
# ===============
# 1	SrWrWr
#
# voice, draw square
# ==================
# 1	V_Wr
# 1	V_Ww
#
# select, formation ui
# ====================
# 1
# 1	OrOrWw
# 1	Srw
#
# select/drag around
# ==================
# 1	Orw
# 1	SrDr
# 1	SrDrDr
# 1	SrDrw
# 1	SrDrwDw
# 1	SrTwWwWw
# 1	SrWr
# 1	SrWrW_
# 1	SrWw
# 1	SrWwDw
# 1	Wr
# 2	SrDw
#
# tap, ui stop
# ============
# 1	SrTwTw
#
# drag robot
# ==========
# 1	DrDrDraSrDra
# 1	DrDraSrDrDraTa
# 1	DrDrwDa
# 1	DraOraOraOraOra
# 1	DraSrTa
# 1	DraSrTaDrDrDra
# 1	DraTa
# 1	DraTaSrTaDrDra
# 1	DrwDrwDra
# 1	TaWrTa
# 1	WrSrWra
# 1	WraTa
# 1	WraWraOraWra
# 2	DraDra
# 5	Wra
# 13	Dra
#
# draw "R"
# ========
# 1	Ww
#
# drag crate
# ==========
# 1	DcaOr
# 1	Drca
# 1	OaOaOc
# 1	Oc
# 1	WcDcaTa
# 1	WcaSr
# 1	WcaWrca
# 1	WwWwWrwWc
# 2	DcaW_
# 5	Wca
# 11	Dca
#
# tap, move corner
# ================
# 1	SrTw
#
# cut
# ===
# 1	DrDrD_
# 1	Wrw
# 1	Ww
# 1	WwWw
# 8	Wr
#
# draw squiggle
# =============
# 1	Dr
# 1	Or
# 1	WrSrWr
#
# draw two spirals
# =================
# 1	Ow
#
# select/ui/draw
# ==============
# 1	SrWrTwWwW_
# 1	SrWwWw
#
# 2x select/tap
# =============
# 1	SrDr2wSrDr2wTw3wTw
# 1	SrTaSrTbTaTb
# 1	SrTbTbSrTaTb
#
# draw "C -> A"
# =============
# 1
#
# select/ui
# =========
# 1	Sr2wTwSrWw
# 1	Srw
# 6	Sr
#
# organize positions
# ==================
# 1	SrPrDrwSrDrwSrPrPrDrwSrDrw
#
# multi drag partway around
# =========================
# 1	DrDrDrDrDrDr
# 1	WrWrWrWwWwWwWwWw
#
# ui recolor
# ==========
# 1	Sr
#
# ui/select/move crate
# ====================
# 1	SrScDca
#
# voice/chop
# ==========
# 1	V_Ow
#
# chop
# ====
# 1	OrOr
# 2	Or
#
# opening fists
# =============
# 1	Or
#
# multi drag back
# ===============
# 1	Wr
#
# select/5f scatter
# =================
# 2	SrOr
#
# select & around
# ===============
# 1	DaSrDa
# 1	SrD_Dra
# 1	SrDa
# 1	SrWa
# 1	WrWaWrWa
#
# select/pinch
# ============
# 1	SrPr
#
# cut & push
# ==========
# 1	DrOrOrOrOr
#
# 2 tap
# =====
# 1	Ta
#
# draw circle whitespace
# ======================
# 1	Ww
#
# draw "C->A"
# ===========
# 1	WawWwWwWwWwWwTwTaTaWcWcScWwWwTw
#
# select/doubletap whitespace
# ===========================
# 1	Sr2w
#
# select/drag
# ===========
# 1	Dr
# 1	DrDra
# 1	DrDraDraSrDraSrDraTa
# 1	DrSrTwTa
# 1	DrTa
# 1	DraDrDr
# 1	DraDraDrDrDraOr
# 1	SrDrDa
# 1	SrDrDra
# 1	SrDraDraDraSrDraDra
# 1	SrDw
# 1	SrTwSrTwSrTw
# 1	SrWr
# 1	SrWrSrDrw
# 1	SrWrWr
# 1	SrWraSrWrb
# 2	SrWra
# 3	SrDr
# 6	SrDra
#
# drag offscreen
# ==============
# 1	Dw
# 1	Or
# 1	SrDrw
# 1	SrOr
# 1	TwDrw
# 1	Wr
# 1	WrDrw
# 3	Drw
#
# sweep
# =====
# 1	Or
# 1	OrOrOrOr
# 1	OrOrOrWr
# 1	OrOra
# 1	OrbOra
# 1	OrwOw
# 1	Ow
# 2	OrOrOr
# 2	Orw
# 3	OrOr
#
# to, select A
# ============
# 1	Ora
#
# sweep around screen
# ===================
# 1	OrOw
#
# tap & draw "0.5"
# ================
# 1	2a3aWwTwWwWw
#
# draw line behind robots
# =======================
# 1	Tw
#
# select/draw
# ===========
# 1	Drw
# 1	Or
# 1	SrWw3w
# 1	SrWwDrW_WwWr
# 2	SrWw
#
# draw wall
# =========
# 1	DrOr
# 1	Wrab
# 1	Ww2w
# 1	WwT_
# 2	Ww
#
# ui/object/target
# ================
# 1	ScTa
# 1	TwSrwTwV_ScDca
#
# select, ui, area
# ================
# 1	SrDa
#
# single moves
# ============
# 1
# 1	DrDrDrDrDrDrDrDrDr
# 1	DrDrDrDrDrOrDrDrWw
# 1	DrDrDrDrDraDrV_Va
# 1	DrDrDrSrPrPrDrwSrPrPrDrSrPrPrDrSrPrPrDrDw
# 1	DrDraDraDraDraDraDraDraDraDraDraDraDrbDrbDrbDrbDrbDrbDrbDrbDrb
# 1	DraDraDraDraDrTaTa
# 1	DraDraDraDraDraDraDraDra
# 1	DraDraDraDraDraDraDraDraDra
# 1	DraDraDraDraDraDraDraDraDraDra
# 1	DraDraDraDraDraDraDraDraDraDraDraDrbDrbDrbDrbDrbDrbDrbDrbDrbDrbDrb
# 1	DraDraDraDraDraDraDrbDraDrbDraDrbDraDrbDraDrbDraDrbDra
# 1	DraDraDraDraDraDrbDrbDrbDrbDrb
# 1	DraDraDraDraDrbDrbDrbDrbDrb
# 1	DraDraDraDrb
# 1	DraDraSrDraSrDraDra2w2wSrDraDraSrDrwDraDraSrDraDra
# 1	DrbDrbDrbDrbDraDrbDrDrDr
# 1	DrwDrwDrwDrwDrwDrw
# 1	SrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTw
# 1	SrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTw
# 1	SrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTwSrTw
# 1	SrTwSrTwSrTwSrTwSrwSrTw
# 1	Wr
# 1	WrWr
# 1	WwWwWwWw
# 2	DrDrDrDrDrDrDr
# 2	DrDrDrDrDrDrDrDr
# 2	DrDrDrDrDrDrDrDrDrDr
# 2	WrWrWrWrWrWr
#
# draw "SQ"
# =========
# 1	WrWrSr
#
# 4f scatter
# ==========
# 1	Or
#
# select, draw square
# ===================
# 1	SrTwOr
# 1	SrTwWwTwWw
# 1	SrWw
# 1	SrWw3_
# 1	TwWw
#
# select/multi rev pinch
# ======================
# 1	SrRr
#
# cut/r pinch
# ===========
# 1	SrWrRr
#
# position/move
# =============
# 1	DcwDca
# 1	DrcDcDrcDca
# 1	DrcDcaDrca
# 1	DrcDrcDca
# 1	DrcDrcDcaDa
# 1	DrcDrcDcaDrcDrcDa
# 1	DrcDrcDrcDrcSc2wDrcDrcDrcDrcTa
# 1	DrcDrcDrcDrca
# 1	DrcV_ScDca
# 1	Or
# 1	OrDrcDcaDaDcDa
# 1	OrOr
# 1	OrOrOrDca
# 1	OrwDcDcDcDca
# 1	S_ScDcaDcaDa
# 1	ScDcaDcDcwDaw
# 1	SrDrcDcDcaTaDcbDcaDcaDa
# 1	SrDrcDca
# 1	SrDrcDrca
# 1	SrDrcScDca
# 1	SrDrcSrWcScwSrDrcScwWcScDca
# 1	SrScSrScSrcScSrScSrScSrScTa
# 1	SrScTa
# 1	SrT_OrcbTa
# 1	SrT_OrwOrwTa
# 1	SrTwDa
# 1	SrWcScwSrWcScwScDca
# 1	SrWrca
# 1	SrWwWwDc
# 1	TawOwDrcDcaDcDa
# 1	V_DrcDca
# 1	WcDca
# 1	WcTaDca
# 1	WrWrWrc
# 1	WraWcaWcaWcaWraWrWrWrWca
# 1	Wrca
# 2	ScDrca
# 2	Vrca
# 2	WrWr
# 3	DrcDca
# 3	Drca
#
# multi sweep
# ===========
# 1	OrOr
#
# set waypoints
# =============
# 1	DrTaTaTaTaSr
# 1	Sr2aTaTaTaTaTaTa
#
# select/move offscreen
# =====================
# 1	SrWrw
#
# ui remove
# =========
# 1
# 1	Sr
# 1	SrTwTw
#
# spread 2f tap
# =============
# 1	Or
#
# tap crate, robot, A
# ===================
# 1	ScSrTa
#
# split & drag
# ============
# 1	OrwOrOr
#
# patrol ui
# =========
# 1	Dw
# 1	Sr
# 1	SrT_T_Sr
# 1	TwWw
#
# to area, not around
# ===================
# 1	DraDraDr
#
# tap/tap
# =======
# 1	ScTa
#
# draw, draw "L"
# ==============
# 1	WwWw
#
# multi drag robot
# ================
# 1	Wra
#
# fist circle, move edge
# ======================
# 1	OrOrOr
#
# position/no move
# ================
# 1	SrTwTw
#
# no action
# =========
# 1
#
# ui/waypoint
# ===========
# 1	SrSc2aScTa
# 1	T_TaSr
#
# draw square
# ===========
# 1	Drw
# 1	SrWrw
# 1	SrWw
# 1	SrwWrwSrwWrwWrwSrw
# 1	WwSrwWw
# 2	Wr
# 3	Ww
# 4	Wrw
#
# drag back
# =========
# 1	DrWw
# 1	Dra
# 1	Or
# 1	Wr
# 2	Dr
#
# drag off edge
# =============
# 1	Drw
#
# hold, ui remove
# ===============
# 1
#
# select, to & around
# ===================
# 1	SrDra
# 1	SrWaWa
#
# multiple drag
# =============
# 1	DrbDaDaDb
# 1	DrbDra
#
# drag from robots
# ================
# 1	Dr
# 1	DrDrwDrD_
# 1	Drw2_
# 1	Orw
# 1	WrWr
# 1	Wrw
#
# multiple select and draw parts
# ==============================
# 1	WwWwSrWrwWrwWrwWrwTwDwDwDwDwWrwWrwWrw
#
# select/waypoint
# ===============
# 1	SrTwTwTwTwTwTwTwWwTwWwTwTwTwTwTwTw
#
# doubletap each robot
# ====================
# 1	Sr
#
# to & squiggle over
# ==================
# 1	Wra
#
# spread/sweep
# ============
# 1	Or
# 1	OrOr
# 1	OrOrOr
#
# draw square as multiple lines
# =============================
# 1	WrWrWrWr
#
# voice
# =====
# 1	V_OwOwOwOw
# 1	V_Pr
# 1	V_Wr
# 1	Va
# 2	V_
# 2	Vrw
# 3	Vr
#
# ui stop
# =======
# 1
#
# ui/draw
# =======
# 1	DrTwTwTwWw
#
# draw "P" in a circle
# ====================
# 1	WwTwWw
#
# tap
# ===
# 1	Dw
# 1	SrTw
# 10	Sr
#
# ccw lasso
# =========
# 1	Sr
#
# drag robots back
# ================
# 1	Dr
# 1	OrO_
#
# to & around
# ===========
# 1	DrDrDrDrDrwDrwDrwDrwDa
# 1	DraDa
# 1	DraDra
# 1	DraRa
# 1	DraVa
# 1	OrDraDraDra
# 1	Orw
# 1	SrDrDrwDraDr
# 1	SrDra
# 1	SrDraW_W_DraDraWraDra
# 1	SrWra
# 7	Dra
#
# ui delete
# =========
# 1	Rr
# 1	Sr
# 1	Sr2wWrwTw
#
# leave behind
# ============
# 1	Drw
# 1	SrDr
#
# lots of drags
# =============
# 1	WrWr
#
# border
# ======
# 1	Da
# 1	DaDa
# 1	DaDaOr
# 1	DaDra
# 1	Drw
# 1	DwTw
# 2	Wa
# 4	Dw
# 4	Ww
#
# no interaction
# ==============
# 3
#
# doubletap
# =========
# 3	Sr
#
# squiggle
# ========
# 1	Drw
# 1	Ww
# 2	Dr
#
# select & path
# =============
# 1	SrWaDa
#
# group moves
# ===========
# 1	2wDr
# 1	DrDrDrDrDrDrDrDr
# 1	DrDrDrDrDrDrDrDrDr
# 1	DrDrW_DrW_DrW_DrW_DrW_DrW_DrW_DrW_
# 1	DrDrwDrDrDrDrDrDrDr
# 1	SrDrDrDrDr
# 1	WrWrWwWrWrWrWrWr
#
# move corner
# ===========
# 1	Vr
#
# move wall
# ==========
# 1	Dr
#
# tap crate tap a
# ===============
# 1	ScTa
#
# ui, border
# ==========
# 1
#
# 4f spread
# =========
# 1	DwOwOw
#
# doubletap robot
# ===============
# 3	Sr
#
# drag
# ====
# 1
# 1	DrDrDr
# 1	DrDrwDa
# 1	DrT_
# 1	DraDra
# 1	DraTa
# 1	Drb
# 1	DrbDbDra
# 1	DrbDraDrb
# 1	DrbDrbDraDra
# 1	DrwDrwDrw
# 1	SrWra
# 1	WraWra
# 1	Wrab
# 2	DraDrbDraDrb
# 2	Wr
# 2	WrWr
# 3	DraDr
# 3	Or
# 4	OrOr
# 4	WraWrb
# 4	WrbWra
# 6	Dr
# 6	DrDr
# 6	Wra
# 14	Dra
# 14	DrbDra
# 25	DraDrb
#
# to & ui
# =======
# 1	DraSrTaSrTaSraSraSraSrDaTw
#
# rev pinch
# =========
# 7	Rr
#
# multiple sweeps
# ===============
# 1	OrbOrbOra
#
# select, ui, path
# ================
# 1	SrWa
#
# voice
# ======
# 1	Sr
# 1	V_
#
# draw line
# =========
# 1	DwDrw
# 1	Ww
# 1	WwTwWw
# 2	Dr
#
# spiral on robot then off screen
# ===============================
# 1	Wr
#
# bottom of screen
# ================
# 1	Wr
#
# no command
# ==========
# 1	DwDwDwDwDwSr
#
# to & across
# ===========
# 1	OrOa
# 1	Vra
# 1	WrWrWrWraWr
#
# doubletap whitespace
# ====================
# 2	2w
#
# use screen edges
# ================
# 1	SrwTwSwTwTwTwTwSrwD_D_DwSwDw
#
# edge
# ====
# 1	OrOrDrw
# 1	SrDrw
# 1	Wr
#
# push
# ====
# 1	OrOr
#
# voice, no interaction
# =====================
# 1	Vr
#
# tap robots
# ==========
# 1	Sr
#
# tap/ui
# ======
# 1	SrwOr
